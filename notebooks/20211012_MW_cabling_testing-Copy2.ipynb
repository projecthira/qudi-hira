# %%
import numpy as np
import os
import pandas as pd

import matplotlib.pyplot as plt

# %%
folder = os.path.join("Z:\\", "Data\\20211115_MW_tip_membrane_tests", "testing_DC_contacts_cryo_top")

# %%
os.listdir(folder)
# Out:
# ['excitation.txt', 'empty_ref_line.txt', 'readout.txt', 'preamp_ground.txt']

# %%
# %matplotlib notebook

folder = os.path.join("Z:\\", "Data\\20211115_MW_tip_membrane_tests", "testing_DC_contacts_cryo_top")
fig, ax = plt.subplots()

for filename in os.listdir(folder):
    df = pd.read_csv(os.path.join(folder, filename), skiprows=4, sep="\t")
    name, _ = os.path.splitext(filename)
    name = name[0:].replace("_", " ")
    print(name[3:])
    ax.plot(df["Time"] * 1e9, df["Ampl"], linewidth=0.5, label=f"{name}")
    
ax.set_xlim([-10, 150])
fig.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">
# ty ref line
# dout
# amp ground
# itation

# %%
base = 40 / 2
delays = np.array([70]) / 2

deltaT = delays - base
print(deltaT * 1e-9 * 2 * 1e8)
# Out:
# [3.]

# %% [markdown]
# $RF = \frac{R_{sc} - 50} {(R_{sc} + 50)}$

# %%
def resistance(rf):
    return -50 * (1 + rf) / (rf - 1)

rf = np.linspace(-0.9, 0.9, 100)
fig, ax = plt.subplots()
ax.plot(rf, resistance(rf))
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %%
print(resistance(-0.6))
# Out:
# 12.5

# %%
folder = os.path.join("Z:\\", "Data", "20211116_MW_cabling_testing", "ContactTestingMeasurementHead")

# %%
os.listdir(folder)
# Out:
# ['C2_SampleLowerPin.txt', 'C2_reference.txt']

# %%
# %matplotlib notebook

fig, ax = plt.subplots()

for filename in os.listdir(folder):
    df = pd.read_csv(os.path.join(folder, filename), skiprows=4, sep=",")
    name, _ = os.path.splitext(filename)
    name = name[3:].replace("_", " ")
    print(name[3:])
    ax.plot(df["Time"] * 1e9, df["Ampl"], linewidth=0.5, label=f"{name}")
    
ax.set_xlim([-10, 200])
fig.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">
# pleLowerPin
# erence
# pleUpperPin
# UpperPin
# LowerPin

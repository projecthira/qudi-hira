# %%
import numpy as np
import os
import pandas as pd

import matplotlib.pyplot as plt

# %%
folder = os.path.join("Z:\\", "Data", "20211012_MW_cabling_testing")

# %%
os.listdir(folder)
# Out:
# ['C2_tip_out.txt',
#  'C2_open_at_top_of_cryo.txt',
#  'C2_sample_in.txt',
#  'C2_sample_out.txt',
#  'C2_tip_in.txt',
#  'C2_open_at_cryo_top2.txt',
#  'C2_tip_in_inside_cryo_topplate.txt',
#  'C2_sample_in_inside_cryo_topplate.txt']

# %%
# %matplotlib notebook

folder = os.path.join("Z:\\", "Data", "20211012_MW_cabling_testing", "10ns_pulse")

fig, ax = plt.subplots()

for filename in os.listdir(folder):
    df = pd.read_csv(os.path.join(folder, filename), skiprows=4)
    name, _ = os.path.splitext(filename)
    name = name[3:-5].replace("_", " ")
    print(name[3:])
    ax.plot(df["Time"] * 1e9, df["Ampl"], linewidth=0.5, label=f"{name}")
    
ax.set_xlim([-10, 150])
fig.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">
# n at cryo top
#  in
# ple in

# %%
base = 39 / 2
delays = np.array([40.5, 41.5, 57.9]) / 2

deltaT = delays - base
print(deltaT * 1e-9 * 2 * 1e8)
# Out:
# [0.15 0.25 1.89]

# %% [markdown]
# $RF = \frac{R_{sc} - 50} {(R_{sc} + 50)}$

# %%
def resistance(rf):
    return -50 * (1 + rf) / (rf - 1)

rf = np.linspace(-0.9, 0.9, 100)
fig, ax = plt.subplots()
ax.plot(rf, resistance(rf))
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %%
print(resistance(-0.6))
# Out:
# 12.5
